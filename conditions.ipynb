# %%
#Conitions
x=10
y=5
if x == y:
    print("true")
elif x > y:
    print("y is less than x")
else:
    print("false")
print("raihan")
# Out:
# y is less than x
# raihan

# %%
#assignment 1
#take values of length an breadth of a rectangle from user input and check if it is square or not.
length = int(input('values of length'))
breadth = int(input('values of breadth'))
if length==breadth:
    print("square")
else:
    print("not square")
# Out:
# not square

# %%
#assigment 2
#Take three integer values from user and print greatest among them.
x = int(input())
y = int(input())
z = int(input())
if x>y and x>z:
    print("X is greater")
elif y>x and y>z:
    print("Y is greater")
else:
    print("Z is greater")
# Out:
# Y is greater

# %%
#assignment 3
#A student will not be allowed in exam if his/her attendance is less than 75%
x = int(input('enter attendance % :'))
y = int(input('enter attendance % :'))
if x>y:
    print("allowed")
else:
    print("not allowed")
# Out:
# not allowed

# %%
#assigment 4
# A school has following rules for grading system:Below 25-F, 25 to 44-E, 45 to 49-D, 50 to 59-C, 60 to 79-B, 80 to 89-A, Above 90 - A+
# Now, Ask user to enter marks and print the corresponding grade
x= int(input('enter the number'))
if x<25:
    print("F")
elif 25<=x<=44:
    print("E")
elif 45<=x<=49:
    print("D")
elif 50<=x<=59:
    print("C")
elif 60<=x<=79:
    print("B")
elif 80<=x<=89:
    print("A")
else:
    print("A+")
# Out:
# D

# %%
from IPython.display import Image
Image('prb.PNG')

# %%
#SOLUTION
amount=0

net_units = float(input("enter my input number: "))

if net_units <= 100:
    amount=0   
elif net_units>100 and net_units<=200:
    amount=(net_units - 100)*5   
elif net_units>200:
    amount=((net_units - 200)*10)+500
print("amount is",amount)
# Out:
# amount is 600.0

# %%
num = float(input('enter any number : '))
if num % 2 == 0 or num % 5 == 0 :
    print(num,'divisible by 5 and 2')
else:
    print('no 2')
# Out:
# 25.0 divisible by 5 and 2
